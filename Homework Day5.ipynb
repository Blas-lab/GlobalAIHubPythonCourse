# %%
class Animal():
    pass
class Dogs():
    pass
class Cats():
    pass

class Animal():
    
    def __init__(self, spice, color, age):
        self.spice = spice
        self.color = color
        self.age = age
        
fox_1 = Animal("fox", "red", 4)
wale_1 = Animal("wale", "blue", 100)
blackmamba_1 = Animal("serpent" , "black", 3)


class Dogs():
    
    def __init__(self, breed, hair, age, name):
        self.breed = breed
        self.hair = hair
        self.age = age
        self.name = name
        
dog_1 = Dogs("gran danese", "brown", 3 , "Madona")
dog_2 = Dogs("foxterrier", "siver blue", 13 , "Nain")
dog_3 = Dogs("chi wa wa" , "white", 5 , "Mr Ruffles")

class Cats():
    
    def __init__(self, breed, hair, age, name, castration, vaccine):
        self.breed = breed
        self.hair = hair
        self.age = age
        self.name = name
        self.castration = castration
        self.vaccine = vaccine
        
cat_1 = Cats("siames", "short", 14 , "Vitorio", "yes", "no")
cat_2 = Cats("persian", "long", 6 , "Prince", "yes", "yes")
cat_3 = Cats("street" , "medium", "unknown" , "Miaw", "no", "no")







print(fox1.color)
print(wale_1.age)
print(blackmamba_1.spice , blackmamba_1.age)

print(dog_1.name , dog_2.name, dog_3.name)
print(dog_1.breed , dog_2.breed, dog_3.breed)
print(dog_1.age , dog_2.age, dog_3.age)

print(cat_1.breed, cat_1.age, cat_1.vaccine)
print(cat_2.breed, cat_2.age, cat_2.vaccine)
print(cat_3.breed, cat_3.age, cat_3.vaccine)
# Out:
# red
# 100
# serpent 3
# Madona Nain Mr Ruffles
# gran danese foxterrier chi wa wa
# 3 13 5
# siames 14 no
# persian 6 yes
# street unknown no
