# %%
# create a List and swap the second half of the list with 
# the first half of the list and print this list on the screen
​
list=["m","i","a","w",1,2,3,4]
​
i=0
j=0
​
buffa=[]
​
type(list)
half_list=int((len(list))/2)
​
for i in range(0, half_list):
    buffa.append(list[i])
​
​
​
list2=[]
​
for j in range( i+1 , len(list)):
    list2.append(list[j]) 
    
​
​
final_list= list2 + buffa
​
type(final_list)
​
​
print(final_list)
<class 'list'>
[1, 2, 3, 4, 'm', 'i', 'a', 'w']
#Ask the user to input a single digit integer to a variable "n"
# then, print the out all of the even numbers from 0 to "n" (includin "n")
​
n = int(input("Please enter a single digit:"))
​
listN=[]
​
for i in range(0,n+1):
    if i%2== 0:
        listN.append(i)
​
    
    
print(listN)
​
​
Please enter a single digit: 9
[0, 2, 4, 6, 8]
# Out:
#   File "<ipython-input-2-21d691282478>", line 3
#     ​
#     ^
# SyntaxError: invalid character in identifier
